# %%
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.gridspec import GridSpec
from matplotlib.dates import DateFormatter
import random
import numpy as np

# %%
nu_var = 8
data = np.random.random((3000, nu_var))

# Update background regions
background_regions = [
    (0, 1000, "white"),
    (1300, 1500, "yellow"),
    (1500, 1600, "red"),
    (1600, 1800, "yellow"),
    (1800, 3000, "white"),
]

# Create subplots
fig, axes = plt.subplots(nu_var, 1, figsize=(12, 14), sharex=True)

for i, ax in enumerate(axes):
    # Add background colors for each subplot
    for start, end, color in background_regions:
        ax.axvspan(start, end, facecolor=color, alpha=0.2)
    
    # Plot the data for the current variable
    ax.plot(data[:, i], label=f"Variable {i+1}")
    ax.set_ylabel(f"Var {i+1}")
    ax.legend(loc="upper right")

# Customize the overall plot
axes[-1].set_xlim(0, 3000)
axes[-1].set_ylim(-5, 5)
axes[-1].set_xlabel("Data Index")

# Adjust layout and show
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
